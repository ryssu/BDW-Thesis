# %% [markdown]
# # Setup
#
# Clone GitHub [repository](https://github.com/ultralytics/yolov5), install [dependencies](https://github.com/ultralytics/yolov5/blob/master/requirements.txt) and check PyTorch and GPU.

# %%
# !git clone https://github.com/ultralytics/yolov5

# %%
# %cd yolov5
# Out:
# c:\Users\Carlos\Desktop\BDW-Thesis\yolov5

# %%
# %pip install -qr requirements.txt comet_ml

# %%
# %pip uninstall -y torch torchvision
# %pip install torch torchvision --index-url https://download.pytorch.org/whl/cu128

# %%
import torch
import utils
display = utils.notebook_init()

print(f"PyTorch version: {torch.__version__}")
print(torch.version.cuda)
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"CUDA version: {torch.version.cuda}")
print(f"GPU: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'None'}")
# Out:
# YOLOv5  v7.0-457-g84ef1e59 Python-3.12.10 torch-2.10.0+cu128 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
# Setup complete  (12 CPUs, 7.7 GB RAM, 413.0/475.7 GB disk)
# PyTorch version: 2.10.0+cu128
# 12.8
# CUDA available: True
# CUDA version: 12.8
# GPU: NVIDIA GeForce RTX 2050

# %% [markdown]
# # Training
#
# Here we train a YOLOv5m model using our custom dataset

# %%
#@title Select YOLOv5 🚀 logger {run: 'auto'}
logger = 'Comet' #@param ['Comet', 'ClearML', 'TensorBoard']

if logger == 'Comet':
  # %pip install -q comet_ml
  import comet_ml; comet_ml.init()
elif logger == 'ClearML':
  # %pip install -q clearml
  import clearml; clearml.browser_login()
elif logger == 'TensorBoard':
  # %load_ext tensorboard
  # %tensorboard --logdir runs/train
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# COMET WARNING: comet_ml.init() is deprecated and will be removed soon. Please use comet_ml.login()

# %%
# !python train.py --imgsz 640 --batch-size -1 --epochs 30 --data bdd100k_cars_foggy.yaml --weights yolov5m.pt --cache ram --patience 5 --project "C:\Users\Carlos\Desktop\Thesis-Runs" --name yolov5m_bdd100k_cars_foggy

# %%
# !python train.py --help
# Out:
# C:\Users\Carlos\AppData\Local\Programs\Python\Python312\python.exe: can't open file 'c:\\Users\\Carlos\\Desktop\\BDW-Thesis\\train.py': [Errno 2] No such file or directory
