# %% [markdown]
# # Setup
#
# Clone GitHub [repository](https://github.com/ultralytics/yolov5), install [dependencies](https://github.com/ultralytics/yolov5/blob/master/requirements.txt) and check PyTorch and GPU.

# %%
# !git clone https://github.com/ultralytics/yolov5

# %%
# %cd yolov5
# Out:
# c:\Users\Carlos\Desktop\BDW-Thesis\yolov5

# %%
# %pip install torch torchvision --index-url https://download.pytorch.org/whl/cu126

# %%
# %pip install -qr requirements.txt comet_ml

# %%
import torch
import utils
display = utils.notebook_init()

print(f"PyTorch version: {torch.__version__}")
print(torch.version.cuda)
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"CUDA version: {torch.version.cuda}")
print(f"GPU: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'None'}")

# %% [markdown]
# # Training
#
# Here we train a YOLOv5m model using our custom dataset

# %%
#@title Select YOLOv5 🚀 logger {run: 'auto'}
logger = 'Comet' #@param ['Comet', 'ClearML', 'TensorBoard']

if logger == 'Comet':
  # %pip install -q comet_ml
  import comet_ml; comet_ml.init()
elif logger == 'ClearML':
  # %pip install -q clearml
  import clearml; clearml.browser_login()
elif logger == 'TensorBoard':
  # %load_ext tensorboard
  # %tensorboard --logdir runs/train
# Out:
# Note: you may need to restart the kernel to use updated packages.
# COMET WARNING: comet_ml.init() is deprecated and will be removed soon. Please use comet_ml.login()

# %% [markdown]
# **Foggy**

# %%
# %run train.py --imgsz 640 --batch-size 2 --epochs 10 --data final_fog.yaml --weights yolov5m.pt --patience 5 --project "C:\Users\Carlos\Desktop\Thesis-Runs\Train" --name yolov5m_final_fog --save-period 5 --workers 2

# %% [markdown]
# **Rainy**

# %%
# %run train.py --imgsz 640 --batch-size 2 --epochs 30 --data final_rain.yaml --weights yolov5m.pt --patience 5 --project "C:\Users\Carlos\Desktop\Thesis-Runs\Train" --name yolov5m_final_rain --workers 2

# %% [markdown]
# In the event of the training being interrupted, continue from last.pt

# %%
# %run train.py --imgsz 640 --batch-size -1 --epochs 30 --data bdd100k_cars_rainy.yaml --weights yolov5m.pt --patience 5 --workers 8 --resume "C:\Users\Carlos\Desktop\Thesis-Runs\Train\yolov5m_bdd100k_cars_rainy\weights\last.pt"
# Out:
# train: weights=yolov5m.pt, cfg=, data=bdd100k_cars_rainy.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=30, batch_size=-1, imgsz=640, rect=False, resume=C:\Users\Carlos\Desktop\Thesis-Runs\Train\yolov5m_bdd100k_cars_rainy\weights\last.pt, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data\hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=5, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5
# YOLOv5  v7.0-457-g84ef1e59 Python-3.12.10 torch-2.10.0+cu126 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
#
# ...

# %% [markdown]
# **Partly Cloudy and Overcast**

# %%
# %run train.py --imgsz 640 --batch-size -1 --epochs 30 --data bdd100k_cars_partlycloudy+overcast.yaml --weights yolov5m.pt --patience 5 --project "C:\Users\Carlos\Desktop\Thesis-Runs\Train" --name yolov5m_bdd100k_cars_partlycloudy+overcast --workers 8
# Out:
# train: weights=yolov5m.pt, cfg=, data=bdd100k_cars_partlycloudy+overcast.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=30, batch_size=-1, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data\hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=C:\Users\Carlos\Desktop\Thesis-Runs\Train, name=yolov5m_bdd100k_cars_partlycloudy+overcast, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=5, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5
# YOLOv5  v7.0-457-g84ef1e59 Python-3.12.10 torch-2.10.0+cu126 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
#
# ...

# %% [markdown]
# In the event of the training being interrupted, continue from last.pt

# %%
# %run train.py --imgsz 640 --batch-size -1 --epochs 30 --data bdd100k_cars_partlycloudy+overcast.yaml --weights yolov5m.pt --patience 5 --workers 8 --resume "C:\Users\Carlos\Desktop\Thesis-Runs\Train\yolov5m_bdd100k_cars_partlycloud+overcast\weights\last.pt"

# %% [markdown]
# **Clear**

# %%
# %run train.py --imgsz 640 --batch-size 2 --epochs 10 --data clear10k2k.yaml --weights yolov5m.pt --patience 5 --project "C:\Users\Carlos\Desktop\Thesis-Runs\Train" --name clear10k2k --workers 8

# %% [markdown]
# **Augmented**

# %%
# %run train.py --imgsz 640 --batch-size 2 --epochs 10 --data augmented.yaml --weights yolov5m.pt --patience 5 --project "C:\Users\Carlos\Desktop\Thesis-Runs\Train" --name augmented10k2k --workers 8

# %% [markdown]
# # Validation
#
# Validate the Model previously trained

# %% [markdown]
# **Foggy**

# %%
# %run val.py --data final_fog.yaml --weights "C:/Users/Carlos/Desktop/Thesis-Runs/Train/yolov5m_final_fog/weights/best.pt" --batch-size 2 --imgsz 640 --task val --workers 2 --save-json --project "C:\Users\Carlos\Desktop\Thesis-Runs\Val" --name yolov5m_final_fog_val
# Out:
# val: data=C:\Users\Carlos\Desktop\BDW-Thesis\yolov5\data\bdd100k_cars_foggy.yaml, weights=['C:/Users/Carlos/Desktop/Thesis-Runs/Train/yolov5m_bdd100k_cars_foggy2/weights/best.pt'], batch_size=2, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=2, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=True, project=C:\Users\Carlos\Desktop\Thesis-Runs\Val, name=yolov5m_bdd100k_cars_foggy_val_results_default, exist_ok=False, half=False, dnn=False
# YOLOv5  v7.0-457-g84ef1e59 Python-3.12.10 torch-2.10.0+cu126 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
#
# Fusing layers...
# Model summary: 212 layers, 20852934 parameters, 0 gradients, 47.9 GFLOPs
# val: Scanning C:\Users\Carlos\Desktop\BDW_Datasets\bdd100k_yolo_cars_foggy\labels\val.cache... 13 images, 0 backgrounds, 0 corrupt: 100%|██████████| 13/13 [00:00<?, ?it/s]
# ...

# %% [markdown]
# **Rainy**

# %%
# %run val.py --data bdd100k_cars_rainy.yaml --weights "C:/Users/Carlos/Desktop/Thesis-Runs/Train/yolov5m_bdd100k_cars_rainy/weights/best.pt" --batch-size 2 --imgsz 640 --task val --workers 2 --save-json --project "C:\Users\Carlos\Desktop\Thesis-Runs\Val" --name yolov5m_bdd100k_cars_rainy_val_results_default
# Out:
# val: data=C:\Users\Carlos\Desktop\BDW-Thesis\yolov5\data\bdd100k_cars_rainy.yaml, weights=['C:/Users/Carlos/Desktop/Thesis-Runs/Train/yolov5m_bdd100k_cars_rainy/weights/best.pt'], batch_size=2, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=2, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=True, project=C:\Users\Carlos\Desktop\Thesis-Runs\Val, name=yolov5m_bdd100k_cars_rainy_val_resultslowerconf, exist_ok=False, half=False, dnn=False
# YOLOv5  v7.0-457-g84ef1e59 Python-3.12.10 torch-2.10.0+cu126 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
#
# Fusing layers...
# Model summary: 212 layers, 20852934 parameters, 0 gradients, 47.9 GFLOPs
# val: Scanning C:\Users\Carlos\Desktop\BDW_Datasets\bdd100k_yolo_cars_rainy\labels\val.cache... 730 images, 0 backgrounds, 0 corrupt: 100%|██████████| 730/730 [00:00<?, ?it/s]
# ...

# %% [markdown]
# **Partly Cloudy and Overcast**

# %%
# %run val.py --data partlycloudy+overcast10k2k.yaml --weights "C:/Users/Carlos/Desktop/Thesis-Runs/Train/partlycloudy+overcast10k2k/weights/best.pt" --batch-size 2 --imgsz 640 --task val --workers 2 --save-json --project "C:\Users\Carlos\Desktop\Thesis-Runs\Val" --name partlycloudy+overcast10k2k_val

# %% [markdown]
# **Clear**

# %%
# %run val.py --data clear10k2k.yaml --weights "C:/Users/Carlos/Desktop/Thesis-Runs/Train/clear10k2k/weights/best.pt" --batch-size 2 --imgsz 640 --task val --workers 2 --save-json --project "C:\Users\Carlos\Desktop\Thesis-Runs\Val" --name clear10k2k_val
# Out:
# val: data=C:\Users\Carlos\Desktop\BDW-Thesis\yolov5\data\bdd100k_cars_clear.yaml, weights=['C:/Users/Carlos/Desktop/Thesis-Runs/Train/yolov5m_bdd100k_cars_clear/weights/best.pt'], batch_size=2, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=2, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=True, project=C:\Users\Carlos\Desktop\Thesis-Runs\Val, name=yolov5m_bdd100k_cars_clear_val_results_default, exist_ok=False, half=False, dnn=False
# YOLOv5  v7.0-457-g84ef1e59 Python-3.12.10 torch-2.10.0+cu126 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
#
# Fusing layers...
# Model summary: 212 layers, 20852934 parameters, 0 gradients, 47.9 GFLOPs
# val: Scanning C:\Users\Carlos\Desktop\BDW_Datasets\bdd100k_yolo_cars_clear\labels\val.cache... 5277 images, 0 backgrounds, 2 corrupt: 100%|██████████| 5278/5278 [00:00<?, ?it/s]
# ...

# %% [markdown]
# **Augmented**

# %%
# %run val.py --data augmented10k2k.yaml --weights "C:/Users/Carlos/Desktop/Thesis-Runs/Train/augmented10k2k/weights/best.pt" --batch-size 2 --imgsz 640 --task val --workers 2 --save-json --project "C:\Users\Carlos\Desktop\Thesis-Runs\Val" --name augmented10k2k_val

# %% [markdown]
# Getting the Average Confidence score

# %%
import json
import numpy as np


# Load predictions
json_path = "C:/Users/Carlos/Desktop/Thesis-Runs/Val/yolov5m_final_fog_val/best_predictions.json"

with open(json_path, 'r') as f:
    predictions = json.load(f)

# Extract all confidence scores
confidences = [pred['score'] for pred in predictions]

# Calculate statistics
print("="*60)
print("FOGGY WEATHER - Confidence Analysis")
print("="*60)
print(f"Total detections: {len(confidences)}")
print(f"Average confidence: {np.mean(confidences):.4f}")
print(f"Median confidence: {np.median(confidences):.4f}")
print(f"Std deviation: {np.std(confidences):.4f}")
print(f"Min confidence: {min(confidences):.4f}")
print(f"Max confidence: {max(confidences):.4f}")
print(f"25th percentile: {np.percentile(confidences, 25):.4f}")
print(f"75th percentile: {np.percentile(confidences, 75):.4f}")
# Out:
# ...
# FOGGY WEATHER - Confidence Analysis
# ...
# Total detections: 24276
# Average confidence: 0.0378
# Median confidence: 0.0030
# Std deviation: 0.1314
# Min confidence: 0.0010
# Max confidence: 0.9373
# 25th percentile: 0.0016
# 75th percentile: 0.0103

# %%
import json
import numpy as np


# Load predictions
json_path = "C:/Users/Carlos/Desktop/Thesis-Runs/Val/yolov5m_final_rain_val/best_predictions.json"

with open(json_path, 'r') as f:
    predictions = json.load(f)

# Extract all confidence scores
confidences = [pred['score'] for pred in predictions]

# Calculate statistics
print("="*60)
print("RAINY WEATHER - Confidence Analysis")
print("="*60)
print(f"Total detections: {len(confidences)}")
print(f"Average confidence: {np.mean(confidences):.4f}")
print(f"Median confidence: {np.median(confidences):.4f}")
print(f"Std deviation: {np.std(confidences):.4f}")
print(f"Min confidence: {min(confidences):.4f}")
print(f"Max confidence: {max(confidences):.4f}")
print(f"25th percentile: {np.percentile(confidences, 25):.4f}")
print(f"75th percentile: {np.percentile(confidences, 75):.4f}")
# Out:
# ...
# RAINY WEATHER - Confidence Analysis
# ...
# Total detections: 19438
# Average confidence: 0.0472
# Median confidence: 0.0038
# Std deviation: 0.1517
# Min confidence: 0.0010
# Max confidence: 0.9628
# 25th percentile: 0.0018
# 75th percentile: 0.0135

# %%
import json
import numpy as np


# Load predictions
json_path = "C:/Users/Carlos/Desktop/Thesis-Runs/Val/partlycloudy+overcast10k2k_val/best_predictions.json"

with open(json_path, 'r') as f:
    predictions = json.load(f)

# Extract all confidence scores
confidences = [pred['score'] for pred in predictions]

# Calculate statistics
print("="*60)
print("PARTLY CLOUDY + OVERCAST WEATHER - Confidence Analysis")
print("="*60)
print(f"Total detections: {len(confidences)}")
print(f"Average confidence: {np.mean(confidences):.4f}")
print(f"Median confidence: {np.median(confidences):.4f}")
print(f"Std deviation: {np.std(confidences):.4f}")
print(f"Min confidence: {min(confidences):.4f}")
print(f"Max confidence: {max(confidences):.4f}")
print(f"25th percentile: {np.percentile(confidences, 25):.4f}")
print(f"75th percentile: {np.percentile(confidences, 75):.4f}")
# Out:
# ...
# PARTLY CLOUDY + OVERCAST WEATHER - Confidence Analysis
# ...
# Total detections: 240383
# Average confidence: 0.0791
# Median confidence: 0.0053
# Std deviation: 0.1973
# Min confidence: 0.0010
# Max confidence: 0.9721
# 25th percentile: 0.0020
# 75th percentile: 0.0292

# %%
import json
import numpy as np


# Load predictions
json_path = "C:/Users/Carlos/Desktop/Thesis-Runs/Val/clear10k2k_val/best_predictions.json"

with open(json_path, 'r') as f:
    predictions = json.load(f)

# Extract all confidence scores
confidences = [pred['score'] for pred in predictions]

# Calculate statistics
print("="*60)
print("CLEAR WEATHER - Confidence Analysis")
print("="*60)
print(f"Total detections: {len(confidences)}")
print(f"Average confidence: {np.mean(confidences):.4f}")
print(f"Median confidence: {np.median(confidences):.4f}")
print(f"Std deviation: {np.std(confidences):.4f}")
print(f"Min confidence: {min(confidences):.4f}")
print(f"Max confidence: {max(confidences):.4f}")
print(f"25th percentile: {np.percentile(confidences, 25):.4f}")
print(f"75th percentile: {np.percentile(confidences, 75):.4f}")
# Out:
# ...
# CLEAR WEATHER - Confidence Analysis
# ...
# Total detections: 225819
# Average confidence: 0.0742
# Median confidence: 0.0052
# Std deviation: 0.1867
# Min confidence: 0.0010
# Max confidence: 0.9718
# 25th percentile: 0.0020
# 75th percentile: 0.0276

# %%
import json
import numpy as np


# Load predictions
json_path = "C:/Users/Carlos/Desktop/Thesis-Runs/Val/augmented10k2k_val/best_predictions.json"

with open(json_path, 'r') as f:
    predictions = json.load(f)

# Extract all confidence scores
confidences = [pred['score'] for pred in predictions]

# Calculate statistics
print("="*60)
print("AUGMENTED WEATHER - Confidence Analysis")
print("="*60)
print(f"Total detections: {len(confidences)}")
print(f"Average confidence: {np.mean(confidences):.4f}")
print(f"Median confidence: {np.median(confidences):.4f}")
print(f"Std deviation: {np.std(confidences):.4f}")
print(f"Min confidence: {min(confidences):.4f}")
print(f"Max confidence: {max(confidences):.4f}")
print(f"25th percentile: {np.percentile(confidences, 25):.4f}")
print(f"75th percentile: {np.percentile(confidences, 75):.4f}")
# Out:
# ...
# AUGMENTED WEATHER - Confidence Analysis
# ...
# Total detections: 248496
# Average confidence: 0.0680
# Median confidence: 0.0052
# Std deviation: 0.1767
# Min confidence: 0.0010
# Max confidence: 0.9712
# 25th percentile: 0.0020
# 75th percentile: 0.0256

# %% [markdown]
# # Detection

# %%
# %run detect.py --help
# Out:
# usage: detect.py [-h] [--weights WEIGHTS [WEIGHTS ...]] [--source SOURCE]
#                  [--data DATA] [--imgsz IMGSZ [IMGSZ ...]]
#                  [--conf-thres CONF_THRES] [--iou-thres IOU_THRES]
#                  [--max-det MAX_DET] [--device DEVICE] [--view-img]
#                  [--save-txt] [--save-format SAVE_FORMAT] [--save-csv]
#                  [--save-conf] [--save-crop] [--nosave]
#                  [--classes CLASSES [CLASSES ...]] [--agnostic-nms]
#                  [--augment] [--visualize] [--update] [--project PROJECT]
#                  [--name NAME] [--exist-ok] [--line-thickness LINE_THICKNESS]
#                  [--hide-labels] [--hide-conf] [--half] [--dnn]
#                  [--vid-stride VID_STRIDE]
#
# options:
#   -h, --help            show this help message and exit
#   --weights WEIGHTS [WEIGHTS ...]
#                         model path or triton URL
#   --source SOURCE       file/dir/URL/glob/screen/0(webcam)
# ...

# %% [markdown]
# **Foggy**

# %%
# %run detect.py --weights "C:/Users/Carlos/Desktop/Thesis-Runs/Train/yolov5m_bdd100k_cars_foggy/weights/best.pt" --img 640 --conf-thres 0.25 --source "C:/Users/Carlos/Desktop/BDW_Datasets/test" --project "C:/Users/Carlos/Desktop/Thesis-Runs/Detect" --name yolov5m_bdd100k_cars_foggy_detect_results --save-txt --save-csv --save-conf
